# %% [markdown]
# ## LetsGrowMore Internship (November 2021)

# %% [markdown]
# ### Beginner Level Task 2 Image to Pencil Sketch with Python

# %% [markdown]
# ### Author: Yash Trimbake

# %% [markdown]
# ### Importing Libraries

# %%
import cv2
from PIL import Image
from IPython.display import display

# %% [markdown]
# ### Loading the image

# %%
img = cv2.imread("photo-1600804340584-c7db2eacf0bf.jpg")
rgb_img =  cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
display(Image.fromarray(rgb_img))
# Out:
# <PIL.Image.Image image mode=RGB size=266x400 at 0x26E923F8910>

# %% [markdown]
# ### Converting Image to Greyscale Image

# %%
grayscale_img = cv2.cvtColor(rgb_img, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(grayscale_img))
# Out:
# <PIL.Image.Image image mode=L size=266x400 at 0x26E94E160D0>

# %% [markdown]
# ### Converting the Image to Negative Image

# %%
invert_img = 255 - grayscale_img
display(Image.fromarray(invert_img))
# Out:
# <PIL.Image.Image image mode=L size=266x400 at 0x26E94E162E0>

# %% [markdown]
# ### Smoothening the Image

# %%
blur_img = cv2.GaussianBlur(invert_img, (21,21), 0)  #Blur the image by gaussian function
display(Image.fromarray(blur_img))
# Out:
# <PIL.Image.Image image mode=L size=266x400 at 0x26E94F59C10>

# %% [markdown]
# ### Invert the blurred image

# %%
invert_blur_img = 255 - blur_img
display(Image.fromarray(invert_blur_img))
# Out:
# <PIL.Image.Image image mode=L size=266x400 at 0x26E94E160D0>

# %% [markdown]
# ### Converting Image into Pencil Sketch

# %%
pencil_sketch_img = cv2.divide(grayscale_img, invert_blur_img, scale=256.0)
display(Image.fromarray(pencil_sketch_img))
# Out:
# <PIL.Image.Image image mode=L size=266x400 at 0x26E94E16520>
