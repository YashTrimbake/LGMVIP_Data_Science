# %% [markdown]
# ## LetsGrowMore Internship (November 2021)

# %% [markdown]
# ### Beginner Level Task 5 Stock Market Prediction And Forecasting Using Stacked LSTM

# %% [markdown]
# Dataset Link: https://raw.githubusercontent.com/mwitiderrick/stockprice/master/NSE-TATAGLOBAL.csv

# %% [markdown]
# ### Author: Yash Trimbake

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_datasets as tdfs
from tensorflow import keras

# %% [markdown]
# ### Loading the dataset

# %%
stock_data = pd.read_csv('NSE-TATAGLOBAL.csv')

# %%
stock_data.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %%
stock_data
# Out:
#             Date    Open    High     Low    Last   Close  \
# 0     2018-09-28  234.05  235.95  230.20  233.50  233.75
# 1     2018-09-27  234.55  236.80  231.10  233.80  233.25
# 2     2018-09-26  240.00  240.00  232.50  235.00  234.25
# 3     2018-09-25  233.30  236.75  232.00  236.25  236.10
# 4     2018-09-24  233.55  239.20  230.75  234.00  233.30
# ...          ...     ...     ...     ...     ...     ...
# 2030  2010-07-27  117.60  119.50  112.00  118.80  118.65
# 2031  2010-07-26  120.10  121.00  117.10  117.10  117.60
# 2032  2010-07-23  121.80  121.95  120.25  120.35  120.65
# 2033  2010-07-22  120.30  122.00  120.25  120.75  120.90
# 2034  2010-07-21  122.10  123.00  121.05  121.10  121.55
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                  3069914          7162.35
# 1                  5082859         11859.95
# 2                  2240909          5248.60
# 3                  2349368          5503.90
# 4                  3423509          7999.55
# ...                    ...              ...
# 2030                586100           694.98
# 2031                658440           780.01
# 2032                281312           340.31
# 2033                293312           355.17
# 2034                658666           803.56
#
# [2035 rows x 8 columns]

# %%
stock_data.shape
# Out:
# (2035, 8)

# %%
stock_data.describe()
# Out:
#               Open         High          Low         Last       Close  \
# count  2035.000000  2035.000000  2035.000000  2035.000000  2035.00000
# mean    149.713735   151.992826   147.293931   149.474251   149.45027
# std      48.664509    49.413109    47.931958    48.732570    48.71204
# min      81.100000    82.800000    80.000000    81.000000    80.95000
# 25%     120.025000   122.100000   118.300000   120.075000   120.05000
# 50%     141.500000   143.400000   139.600000   141.100000   141.25000
# 75%     157.175000   159.400000   155.150000   156.925000   156.90000
# max     327.700000   328.750000   321.650000   325.950000   325.75000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          2.035000e+03      2035.000000
# mean           2.335681e+06      3899.980565
# std            2.091778e+06      4570.767877
# min            3.961000e+04        37.040000
# 25%            1.146444e+06      1427.460000
# 50%            1.783456e+06      2512.030000
# 75%            2.813594e+06      4539.015000
# max            2.919102e+07     55755.080000

# %%
stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2035 entries, 0 to 2034
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  2035 non-null   object
#  1   Open                  2035 non-null   float64
#  2   High                  2035 non-null   float64
#  3   Low                   2035 non-null   float64
#  4   Last                  2035 non-null   float64
#  5   Close                 2035 non-null   float64
#  6   Total Trade Quantity  2035 non-null   int64
#  7   Turnover (Lacs)       2035 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 127.3+ KB

# %% [markdown]
# ### Checking for Null Values

# %%
stock_data.isnull().sum()
# Out:
# Date                    0
# Open                    0
# High                    0
# Low                     0
# Last                    0
# Close                   0
# Total Trade Quantity    0
# Turnover (Lacs)         0
# dtype: int64

# %% [markdown]
# ### Data Visualisation

# %%
plt.style.use('seaborn')
plt.plot(stock_data['Open'],'b')
plt.xlabel('Stock')
plt.ylabel('Open Price')
# Out:
# Text(0, 0.5, 'Open Price')

# %%
plt.plot(stock_data['Close'],'r')
plt.xlabel('Stock')
plt.ylabel('Close Price')
# Out:
# Text(0, 0.5, 'Close Price')

# %% [markdown]
# ### Scatter Matrix

# %%
from pandas.plotting import scatter_matrix

# %%
cols=['Open','High','Low','Last','Total Trade Quantity','Turnover (Lacs)']

# %%
scatter_matrix(stock_data[cols],figsize=(10,8),grid=True)
# Out:
# array([[<AxesSubplot:xlabel='Open', ylabel='Open'>,
#         <AxesSubplot:xlabel='High', ylabel='Open'>,
#         <AxesSubplot:xlabel='Low', ylabel='Open'>,
#         <AxesSubplot:xlabel='Last', ylabel='Open'>,
#         <AxesSubplot:xlabel='Total Trade Quantity', ylabel='Open'>,
#         <AxesSubplot:xlabel='Turnover (Lacs)', ylabel='Open'>],
#        [<AxesSubplot:xlabel='Open', ylabel='High'>,
#         <AxesSubplot:xlabel='High', ylabel='High'>,
#         <AxesSubplot:xlabel='Low', ylabel='High'>,
#         <AxesSubplot:xlabel='Last', ylabel='High'>,
#         <AxesSubplot:xlabel='Total Trade Quantity', ylabel='High'>,
#         <AxesSubplot:xlabel='Turnover (Lacs)', ylabel='High'>],
#        [<AxesSubplot:xlabel='Open', ylabel='Low'>,
#         <AxesSubplot:xlabel='High', ylabel='Low'>,
#         <AxesSubplot:xlabel='Low', ylabel='Low'>,
#         <AxesSubplot:xlabel='Last', ylabel='Low'>,
#         <AxesSubplot:xlabel='Total Trade Quantity', ylabel='Low'>,
#         <AxesSubplot:xlabel='Turnover (Lacs)', ylabel='Low'>],
#        [<AxesSubplot:xlabel='Open', ylabel='Last'>,
#         <AxesSubplot:xlabel='High', ylabel='Last'>,
#         <AxesSubplot:xlabel='Low', ylabel='Last'>,
#         <AxesSubplot:xlabel='Last', ylabel='Last'>,
#         <AxesSubplot:xlabel='Total Trade Quantity', ylabel='Last'>,
#         <AxesSubplot:xlabel='Turnover (Lacs)', ylabel='Last'>],
#        [<AxesSubplot:xlabel='Open', ylabel='Total Trade Quantity'>,
#         <AxesSubplot:xlabel='High', ylabel='Total Trade Quantity'>,
#         <AxesSubplot:xlabel='Low', ylabel='Total Trade Quantity'>,
#         <AxesSubplot:xlabel='Last', ylabel='Total Trade Quantity'>,
#         <AxesSubplot:xlabel='Total Trade Quantity', ylabel='Total Trade Quantity'>,
#         <AxesSubplot:xlabel='Turnover (Lacs)', ylabel='Total Trade Quantity'>],
#        [<AxesSubplot:xlabel='Open', ylabel='Turnover (Lacs)'>,
#         <AxesSubplot:xlabel='High', ylabel='Turnover (Lacs)'>,
#         <AxesSubplot:xlabel='Low', ylabel='Turnover (Lacs)'>,
#         <AxesSubplot:xlabel='Last', ylabel='Turnover (Lacs)'>,
#         <AxesSubplot:xlabel='Total Trade Quantity', ylabel='Turnover (Lacs)'>,
#         <AxesSubplot:xlabel='Turnover (Lacs)', ylabel='Turnover (Lacs)'>]],
#       dtype=object)

# %% [markdown]
# ### In stock market, profit or loss is determined by closing price of a stock for the day.

# %%
stock_data['Date']=pd.to_datetime(stock_data.Date,format='%Y-%m-%d')
stock_data.index=stock_data['Date']

# %%
plt.figure(figsize=(16,8))
plt.plot(stock_data['Close'],label='Close Price History')
plt.xlabel('Year')
plt.ylabel('Close Price')
# Out:
# Text(0, 0.5, 'Close Price')

# %% [markdown]
# ### Training and testing of data

# %%
X=stock_data[["Close"]]

# %%
X.head()
# Out:
#              Close
# Date
# 2018-09-28  233.75
# 2018-09-27  233.25
# 2018-09-26  234.25
# 2018-09-25  236.10
# 2018-09-24  233.30

# %%
Y=stock_data["Close"].values

# %%
size=int(X.shape[0]*0.8)
size
# Out:
# 1628

# %%
train=X.iloc[:size]
test=X.iloc[size:]

# %%
print(train.shape)
print(test.shape)
# Out:
# (1628, 1)
# (407, 1)

# %%
plt.plot(test,label="Testing_data")
plt.plot(train,label="Training_data")
plt.legend()

# %%
from sklearn.preprocessing import MinMaxScaler
ms=MinMaxScaler()
ms.fit(train)
s_train=ms.transform(train)
s_test=ms.transform(test)

# %% [markdown]
# ### Stacked LSTM implementation

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
model=Sequential()
model.add(LSTM(100,return_sequences=True,activation="relu",input_shape=(10,1)))
model.add(LSTM(100,activation="relu"))
model.add(Dense(1))
model.compile(loss="mse",optimizer="adam")

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 10, 100)           40800
#
#  lstm_1 (LSTM)               (None, 100)               80400
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 121,301
# Trainable params: 121,301
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.preprocessing.sequence import TimeseriesGenerator
gen=TimeseriesGenerator(s_train,s_train,length=10,batch_size=10)

# %%
model.fit_generator(gen,epochs=55,steps_per_epoch=15)
# Out:
# <ipython-input-27-526c22658254>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(gen,epochs=55,steps_per_epoch=15)
# Epoch 1/55
# 15/15 [==============================] - 2s 8ms/step - loss: 0.0384
# Epoch 2/55
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0229
# Epoch 3/55
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0102
# Epoch 4/55
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0091
# Epoch 5/55
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0033
# Epoch 6/55
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0056
# Epoch 7/55
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0022
# Epoch 8/55
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0142
# Epoch 9/55
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0076
# Epoch 10/55
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0060
# Epoch 11/55
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0063
# Epoch 12/55
# 15/15 [==============================] - 0s 7ms/step - loss: 8.4281e-04
# Epoch 13/55
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 14/55
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 15/55
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0012
# Epoch 16/55
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0023
# Epoch 17/55
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0018
# Epoch 18/55
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0024
# Epoch 19/55
# 15/15 [==============================] - 0s 7ms/step - loss: 7.4472e-04
# Epoch 20/55
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0012
# Epoch 21/55
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0020
# Epoch 22/55
# 15/15 [==============================] - 0s 7ms/step - loss: 4.1668e-04
# Epoch 23/55
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 24/55
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 25/55
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0027
# Epoch 26/55
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0029
# Epoch 27/55
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 28/55
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0011
# Epoch 29/55
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 30/55
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0021
# Epoch 31/55
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0029
# Epoch 32/55
# 15/15 [==============================] - 0s 9ms/step - loss: 6.9726e-04
# Epoch 33/55
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 34/55
# 15/15 [==============================] - 0s 8ms/step - loss: 7.9374e-04
# Epoch 35/55
# 15/15 [==============================] - 0s 8ms/step - loss: 6.0144e-04
# Epoch 36/55
# 15/15 [==============================] - 0s 8ms/step - loss: 8.6587e-04
# Epoch 37/55
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0024
# Epoch 38/55
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 39/55
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 40/55
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 41/55
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0026
# Epoch 42/55
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 43/55
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 44/55
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 45/55
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 46/55
# 15/15 [==============================] - 0s 8ms/step - loss: 7.2094e-04
# Epoch 47/55
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0011
# Epoch 48/55
# 15/15 [==============================] - 0s 8ms/step - loss: 9.2921e-04
# Epoch 49/55
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0031
# Epoch 50/55
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0032
# Epoch 51/55
# 15/15 [==============================] - 0s 7ms/step - loss: 9.0164e-04
# Epoch 52/55
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 53/55
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 54/55
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 55/55
# 15/15 [==============================] - 0s 8ms/step - loss: 7.6029e-04

# %% [markdown]
# ### Testing generating Time Series Data

# %%
gen_test=TimeseriesGenerator(s_test,s_test,length=10,batch_size=1)

# %%
xtest=[]
ytest=[]
for i in range(len(gen_test)):
  x,y=gen_test[i]
  xtest.append(x[0])
  ytest.append(y[0][0])

# %%
xtest[0]
# Out:
# array([[0.07956074],
#        [0.08023308],
#        [0.09278351],
#        [0.10264455],
#        [0.08090542],
#        [0.04661587],
#        [0.0775437 ],
#        [0.07776782],
#        [0.06521739],
#        [0.08135365]])

# %%
pred=model.predict(gen_test)

# %%
actual=ms.inverse_transform(np.array(ytest).reshape(-1, 1))
pred=ms.inverse_transform(pred)

# %%
plt.plot(actual,label="Original")
plt.plot(pred,label="Predicted")
plt.legend()
